# %% [markdown]
# # Недвижимость в Сиэттле
#
# Имеются данные о продажной стоимости недвижимости в Сиэтле для 50 сделок в 2001 году и 50 в 2002. Изменились ли цены?

# %%
import numpy as np
import matplotlib.pylab as plt
import scipy.stats as st
import seaborn as sns
import pandas as pd

# %%
# перестановочный критерий
from permute.core import two_sample

# бутстрап
from arch.bootstrap import IIDBootstrap

# %%
data = pd.read_csv('./seattle.txt', delimiter='\t')
data.head()
# Out:
#    Price  Year
# 0  142.0  2002
# 1  232.0  2002
# 2  132.5  2002
# 3  200.0  2002
# 4  362.0  2002

# %% [markdown]
# boxplot

# %%
sns.boxplot(data=data)

# %%
x1 = data.loc[data['Year']==2001]['Price'].values
x2 = data.loc[data['Year']==2002]['Price'].values

# %%
sns.kdeplot(x1, label='2001')
sns.kdeplot(x2, label='2002')

# %% [markdown]
# qq-график

# %%
_= st.probplot(x1 , plot = plt)

# %%
_= st.probplot(x2 , plot = plt)

# %% [markdown]
# Критерий Стьюдента:

# %%
st.ttest_ind(x1,x2)
# Out:
# Ttest_indResult(statistic=-0.8057258725189664, pvalue=0.42235167114691463)

# %% [markdown]
# Критерий Манна-Уитни-Уилкоксона:

# %%
st.mannwhitneyu(x1,x2, alternative= 'two-sided')
# Out:
# MannwhitneyuResult(statistic=1295.5, pvalue=0.7563872675701748)

# %% [markdown]
# Перестановочный критерий:

# %%
two_sample(x1, x2,  alternative='two-sided')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-265cb0c68759> in <module>
# ----> 1 two_sample(x1, x2,  alternative='two-sided')
#
# C:\Apps\anaconda3\lib\site-packages\permute\core.py in two_sample(x, y, reps, stat, alternative, keep_dist, seed, plus1)
#     253
#     254     res = two_sample_core(pot_out_all, nx, tst_fun, alternative=alternative,
# --> 255                           reps=reps, keep_dist=keep_dist, seed=seed, plus1=plus1)
#     256
#     257     if keep_dist:
#
# C:\Apps\anaconda3\lib\site-packages\permute\core.py in two_sample_core(potential_outcomes_all, nx, tst_stat, alternative, reps, keep_dist, seed, plus1)
#     127         These values are only returned if `keep_dist` == True
#     128     """
# --> 129     prng = get_prng(seed)
#     130
#     131     rr = list(range(potential_outcomes_all.shape[0]))
#
# C:\Apps\anaconda3\lib\site-packages\permute\utils.py in get_prng(seed)
#     232     """
#     233     if seed is None:
# --> 234         seed = np.random.randint(0, 10**10) # generate an integer
#     235     if seed is np.random:
#     236         return np.random.mtrand._rand
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: high is out of bounds for int32

# %% [markdown]
# График p-value от числа итераций:

# %%
# ваш код

# %% [markdown]
# Доверительные интервалы для средних значений в выборках с помощью бутстрепа:

# %%
bs = IIDBootstrap(x1)
bs.conf_int(np.mean, 1000, size=0.9, method='bca')
# Out:
# array([[253.66139627],
#        [324.52514553]])

# %%
bs = IIDBootstrap(x2)
bs.conf_int(np.mean, 1000, size=0.9, method='bca')
# Out:
# array([[279.32336588],
#        [437.32675163]])

# %% [markdown]
# Ожидаемые ответы: ```~~~[246, 330], [241,403]```

# %% [markdown]
# Доверительный интервал для разности двух средних с помощью бутстрепа:

# %%
bs = IIDBootstrap( x2 - x1)
bs.conf_int(np.mean, 1000,  method='bca')
# Out:
# array([[-25.22711492],
#        [155.56142511]])

# %% [markdown]
# Ожидаемые ответы: ```[-52, 115]```

# %%
st.ks_2samp(x1,x2)
# Out:
# Ks_2sampResult(statistic=0.14, pvalue=0.7166468440414822)

# %% [markdown]
# **Hesterberg T., Monaghan S., Moore D.S., Clipson A., Epstein R. (2005). Bootstrap methods and permutation tests. In Introduction to the Practice of Statistics, New York: W. H. Freeman and Company.** http://statweb.stanford.edu/~tibs/stat315a/Supplements/bootstrap.pdf
